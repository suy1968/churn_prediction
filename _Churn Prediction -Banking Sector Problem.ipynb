# %% [markdown]
# # Problem Statement: -
# The project was related to banking sector. A bank had details of their customers and whether the customer
# has left the bank (closed his account) or not. The task was to identify which factors contribute towards customer churn and
# build a machine learning model to predict which customers are more likely to leave the bank.

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Importing required libraries -

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %matplotlib inline

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# ### Loading the dataset -

# %%
data = pd.read_csv(r'C:\Users\HP\Desktop\churn_modelling.csv')

# %% [markdown]
# ### Performing EDA -

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
# 2       8 159660.80              3          1               0
# 3       1      0.00              2          0               0
# 4       2 125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5      0.00              2          1               0
# 9996      10  57369.61              1          1               1
# 9997       7      0.00              1          0               1
# 9998       3  75075.31              2          1               0
# 9999       4 130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.sample(7)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 5746       5747    15751131       Moss          836     Spain  Female   41
# 6737       6738    15706223     Barnes          715     Spain    Male   38
# 9673       9674    15784148  Beneventi          643    France    Male   62
# 369         370    15583303    Monaldo          593    France  Female   29
# 4815       4816    15737647     Obioma          775   Germany  Female   77
# 1658       1659    15654851     Obialo          748    France    Male   44
# 4803       4804    15610002   Chidubem          802     Spain    Male   41
#
#       Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5746       7 150302.84              1          1               1
# 6737       2  96798.79              2          1               1
# 9673       9      0.00              2          0               0
# 369        2 152265.43              1          1               0
# 4815       6 135120.56              1          1               0
# 1658       2  92911.52              1          0               1
# 4803       5      0.00              2          1               1
#
#       EstimatedSalary  Exited
# 5746        156036.19       0
# 6737          4554.67       0
# 9673        155870.82       0
# 369          34004.44       0
# 4815         37836.64       0
# 1658         85495.24       0
# 4803        134626.30       0

# %%
data.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.describe().T
# Out:
#                    count        mean      std         min         25%  \
# RowNumber       10000.00     5000.50  2886.90        1.00     2500.75
# CustomerId      10000.00 15690940.57 71936.19 15565701.00 15628528.25
# CreditScore     10000.00      650.53    96.65      350.00      584.00
# Age             10000.00       38.92    10.49       18.00       32.00
# Tenure          10000.00        5.01     2.89        0.00        3.00
# Balance         10000.00    76485.89 62397.41        0.00        0.00
# NumOfProducts   10000.00        1.53     0.58        1.00        1.00
# HasCrCard       10000.00        0.71     0.46        0.00        0.00
# IsActiveMember  10000.00        0.52     0.50        0.00        0.00
# EstimatedSalary 10000.00   100090.24 57510.49       11.58    51002.11
# Exited          10000.00        0.20     0.40        0.00        0.00
#
#                         50%         75%         max
# RowNumber           5000.50     7500.25    10000.00
# CustomerId      15690738.00 15753233.75 15815690.00
# CreditScore          652.00      718.00      850.00
# Age                   37.00       44.00       92.00
# Tenure                 5.00        7.00       10.00
# Balance            97198.54   127644.24   250898.09
# NumOfProducts          1.00        2.00        4.00
# HasCrCard              1.00        1.00        1.00
# IsActiveMember         1.00        1.00        1.00
# EstimatedSalary   100193.91   149388.25   199992.48
# Exited                 0.00        0.00        1.00

# %% [markdown]
# ### Data Cleaning -

# %% [markdown]
# Checking for any missing values -

# %%
data.isna().sum().any()
# Out:
# False

# %% [markdown]
# Checking for any duplicate rows -

# %%
duplicate_rows = data[data.duplicated()]
duplicate_rows.shape[0]
# Out:
# 0

# %% [markdown]
# Dropping all the columns which are not required for the analysis -

# %%
data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %% [markdown]
# Columns with numerical data -

# %%
numerical_data = data.select_dtypes(include='number')
numerical_data.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# Columns with categorical data -

# %%
categorical_data = data.select_dtypes(exclude='number')
categorical_data.columns
# Out:
# Index(['Geography', 'Gender'], dtype='object')

# %% [markdown]
# Checking the outcome labels -

# %%
data['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=data, x='Exited')
plt.show()

# %% [markdown]
# ### Data Visualization (based on categorical features) -

# %% [markdown]
# Customer distribution based on gender -

# %%
data['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
x = data['Gender'].value_counts().values
plt.figure(figsize=(7, 6))
plt.pie(x, center=(0, 0), radius=1.5, labels=['Male', 'Female'], autopct='%1.1f%%', pctdistance=0.5)
plt.axis('equal')
plt.show()

# %% [markdown]
# Customer churn based on gender -

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='Gender', data=data)
plt.show()

# %% [markdown]
# Customer distribution based on geography -

# %%
print(data['Geography'].value_counts())
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
x = data['Geography'].value_counts().values
plt.figure(figsize=(7, 6))
plt.pie(x, center=(0, 0), radius=1.5, labels=['France', 'Germany', 'Spain'], autopct='%1.1f%%', pctdistance=0.5)
plt.axis('equal')
plt.show()

# %% [markdown]
# Customer churn based on geography -

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='Geography', data=data)
plt.show()

# %% [markdown]
# Checking the gender distribution of exited customersbased on their location -

# %%
plt.figure(figsize=(8, 5))
crosstab = pd.crosstab(data['Geography'], data['Gender'], values=data['Exited'], aggfunc=np.sum)
sns.heatmap(crosstab, annot=True, fmt='d')
plt.show()

# %% [markdown]
# Checking the number of active members -

# %%
data['IsActiveMember'].value_counts()
# Out:
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64

# %% [markdown]
# Customer churn based on the factor whether a customer is activite member or not -

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='IsActiveMember', data=data)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(y='IsActiveMember', hue='Gender', data=data)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=data, y='IsActiveMember', hue='Geography')
plt.show()

# %% [markdown]
# Checking the numbers of customers having a credit card -

# %%
data['HasCrCard'].value_counts()
# Out:
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64

# %% [markdown]
# Customer churn based on the factor whether a customer has a credit card or not -

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='HasCrCard', data=data)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(y='HasCrCard', hue='Gender', data=data)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=data, y='HasCrCard', hue='Geography')
plt.show()

# %% [markdown]
# Checking the number of products a customer has subscribed for -

# %%
data['NumOfProducts'].value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64

# %% [markdown]
# Customer churn based on the number of products a customer has a subscribed for -

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='NumOfProducts', data=data)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=data, y='NumOfProducts', hue='Gender')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.countplot(data=data, y='NumOfProducts', hue='Geography')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.set(style="darkgrid")
ax = sns.pointplot(x='Geography', y='CreditScore', hue='Gender', data=data, dodge=True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.set(style="darkgrid")
ax = sns.pointplot(x='Geography', y='Balance', hue='Gender', data=data, dodge=True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.set(style="darkgrid")
ax = sns.pointplot(x='Geography', y='EstimatedSalary', hue='Gender', data=data, dodge=True)
plt.show()

# %% [markdown]
# Checking the distribution of data -

# %%
feat_set1 = ['CreditScore', 'Balance', 'EstimatedSalary']
data[feat_set1].hist(figsize=(15, 8))
plt.show()

# %%
sns.set(style="whitegrid")
fig = plt.figure(figsize=(12, 5))
fig.subplots_adjust(right=1.5)

plt.subplot(1, 3, 1)
sns.boxplot(y=data['CreditScore'])

plt.subplot(1, 3, 2)
sns.boxplot(y=data['Balance'])

plt.subplot(1, 3, 3)
sns.boxplot(y=data['EstimatedSalary'])

plt.show()

# %%
def diagnostic_plot(data, col):
    fig = plt.figure(figsize=(9, 4))
    fig.subplots_adjust(right=1.5)
    
    plt.subplot(1, 2, 1)
    sns.distplot(data[col], kde=True, color='red')
    plt.title('Histogram')
    
    plt.subplot(1, 2, 2)
    stats.probplot(data[col], dist='norm', fit=True, plot=plt)
    plt.title('Q-Q Plot')
    
    plt.show()

# %%
diagnostic_plot(data, 'Balance')

# %%
diagnostic_plot(data, 'CreditScore')

# %%
diagnostic_plot(data, 'EstimatedSalary')

# %%
plt.figure(figsize=(8, 5))
sns.distplot(data['Age'], kde=True, color='red')
plt.show()

# %%
print("Minimum Age is {}".format(data['Age'].min()))
print("Maximum Age is {}".format(data['Age'].max()))
# Out:
# Minimum Age is 18
# Maximum Age is 92

# %%
print("Mean: {:.2f}".format(data['Age'].mean()))
print("Median: {:.2f}".format(data['Age'].median()))
# Out:
# Mean: 38.92
# Median: 37.00

# %% [markdown]
# Checking the correlation between independent variables -

# %%
X = data.drop('Exited', axis=1)
X.corr(method='spearman')
# Out:
#                  CreditScore   Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# CreditScore             1.00 -0.01    0.00     0.01           0.01      -0.00
# Age                    -0.01  1.00   -0.01     0.03          -0.06      -0.02
# Tenure                  0.00 -0.01    1.00    -0.01           0.01       0.02
# Balance                 0.01  0.03   -0.01     1.00          -0.32      -0.01
# NumOfProducts           0.01 -0.06    0.01    -0.32           1.00       0.00
# HasCrCard              -0.00 -0.02    0.02    -0.01           0.00       1.00
# IsActiveMember          0.02  0.04   -0.03    -0.01           0.02      -0.01
# EstimatedSalary         0.00 -0.00    0.01     0.01           0.01      -0.01
#
#                  IsActiveMember  EstimatedSalary
# CreditScore                0.02             0.00
# Age                        0.04            -0.00
# Tenure                    -0.03             0.01
# Balance                   -0.01             0.01
# NumOfProducts              0.02             0.01
# HasCrCard                 -0.01            -0.01
# IsActiveMember             1.00            -0.01
# EstimatedSalary           -0.01             1.00

# %% [markdown]
# Checking the correlation of independent variables with dependent variable -

# %%
X.corrwith(data['Exited'])
# Out:
# CreditScore       -0.03
# Age                0.29
# Tenure            -0.01
# Balance            0.12
# NumOfProducts     -0.05
# HasCrCard         -0.01
# IsActiveMember    -0.16
# EstimatedSalary    0.01
# dtype: float64

# %% [markdown]
# Plotting the Correlation Matrix -

# %%
plt.figure(figsize = (10, 8))
corr = data.corr(method='spearman')
mask = np.triu(np.ones_like(corr, dtype=bool))
cormat = sns.heatmap(corr, mask=mask, annot=True, cmap='YlGnBu', linewidths=1, fmt=".2f")
cormat.set_title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Feature Engineering -

# %%
data['Age Group'] = pd.cut(x=data['Age'], 
                            bins=[18, 40, 60, 95], 
                            labels=['Youngster', 'Middle-Aged', 'Senior Citizen'])

# %%
data['Exited'].groupby(data['Age Group']).sum()
# Out:
# Age Group
# Youngster          684
# Middle-Aged       1236
# Senior Citizen     115
# Name: Exited, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Exited', hue='Age Group', data=data)
plt.show()

# %% [markdown]
# One-hot encoding the categorical features -

# %%
feat_set2 = ['Geography', 'Gender']
data_encoded = pd.get_dummies(data[feat_set2], drop_first=True)
data_encoded.sample(5)
# Out:
#       Geography_Germany  Geography_Spain  Gender_Male
# 6151                  0                1            0
# 1001                  0                0            0
# 6420                  1                0            0
# 5778                  0                0            0
# 9337                  1                0            0

# %%
data = data.join(data_encoded)
data.sample(5)
# Out:
#       CreditScore Geography  Gender  Age  Tenure   Balance  NumOfProducts  \
# 6028          646     Spain  Female   50       5 142644.64              2
# 1893          488    France    Male   34       3      0.00              2
# 1321          724    France    Male   40       6      0.00              2
# 6068          676    France  Female   41       4 101457.14              1
# 4837          803    France    Male   28       3      0.00              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited    Age Group  \
# 6028          1               1        142208.50       1  Middle-Aged
# 1893          1               1        125979.36       0    Youngster
# 1321          0               0        106149.48       0    Youngster
# 6068          1               1         79101.67       0  Middle-Aged
# 4837          1               0        159654.00       0    Youngster
#
#       Geography_Germany  Geography_Spain  Gender_Male
# 6028                  0                1            0
# 1893                  0                0            1
# 1321                  0                0            1
# 6068                  0                0            0
# 4837                  0                0            1

# %%
final_data = data.drop(['Geography', 'Gender', 'Age Group'], axis=1)
final_data.sample(5)
# Out:
#       CreditScore  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 2701          649   31       2      0.00              2          1
# 3750          629   39       2 129669.32              2          1
# 4617          812   24      10      0.00              2          1
# 1624          525   25      10      0.00              2          1
# 9517          543   37       8 140894.06              2          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 2701               0         15200.61       0                  0
# 3750               0         82774.07       0                  0
# 4617               1        156906.15       0                  0
# 1624               0         69361.95       0                  0
# 9517               1        118059.19       0                  1
#
#       Geography_Spain  Gender_Male
# 2701                0            0
# 3750                0            1
# 4617                0            1
# 1624                1            0
# 9517                0            1

# %% [markdown]
# Columns present in the processed data -

# %%
final_data.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male'],
#       dtype='object')

# %% [markdown]
# ### Splitting the data into independent & dependent variables -

# %%
X = final_data.drop('Exited', axis=1)
y = final_data['Exited']

# %% [markdown]
# ### Splitting the data into train & test sets -

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %% [markdown]
# ### Scaling the data -

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Importing performance metrics for binary classification -

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score, precision_score, recall_score, roc_auc_score, roc_curve, auc

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.pipeline import Pipeline
pipeline_lr = Pipeline([('lr', LogisticRegression())])
pipeline_svc = Pipeline([('svc', SVC())])
pipeline_dt = Pipeline([('dt', DecisionTreeClassifier())])
pipeline_knn = Pipeline([('knn', KNeighborsClassifier())])
pipeline_nb = Pipeline([('nb', GaussianNB())])

pipelines = [pipeline_lr, pipeline_svc, pipeline_dt, pipeline_knn, pipeline_nb]

pipe_dict = {0: 'Logistic Regression', 
             1: 'Support Vector Classifier', 
             2: 'Decision Tree Classifier',
             3: 'K-Neighbors Classifier', 
             4: 'Naive Bayes Classifier'}

for pipe in pipelines:
    pipe.fit(X_train, y_train)
    
for i, model in enumerate(pipelines):
    print("{}: {:.2f}".format(pipe_dict[i], model.score(X_test, y_test)))
# Out:
# Logistic Regression: 0.81
# Support Vector Classifier: 0.86
# Decision Tree Classifier: 0.81
# K-Neighbors Classifier: 0.83
# Naive Bayes Classifier: 0.83

# %% [markdown]
# ## Support Vector Classifier

# %% [markdown]
# Let's train our model -

# %%
from sklearn.svm import SVC
svc = SVC(probability=True)
svc.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %% [markdown]
# Predicting the outcome labels for test set -

# %%
y_pred_svc = svc.predict(X_test)
y_pred_proba_svc = svc.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Performance Evaluation

# %%
print("Train accuracy :{:.2f}".format(accuracy_score(y_train, svc.predict(X_train))))
print("Test accuracy :{:.2f}".format(accuracy_score(y_test, svc.predict(X_test))))
# Out:
# Train accuracy :0.87
# Test accuracy :0.86

# %% [markdown]
# Plotting the Confusion Matrix -

# %%
conmat = confusion_matrix(y_test, y_pred_svc)
sns.heatmap(conmat, annot=True, fmt='d')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# Checking the Classification Report -

# %%
print("Classification Report")
print(classification_report(y_test, y_pred_svc))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1595
#            1       0.79      0.44      0.57       405
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.71      0.74      2000
# weighted avg       0.86      0.86      0.85      2000

# %%
print("F1 Score: {:.2f}".format(f1_score(y_test, y_pred_svc)))
print("Precision: {:.2f}".format(precision_score(y_test, y_pred_svc)))
print("Recall: {:.2f}".format(recall_score(y_test, y_pred_svc)))
# Out:
# F1 Score: 0.57
# Precision: 0.79
# Recall: 0.44

# %% [markdown]
# Calculating area under the ROC curve -

# %%
print("AUC Score: {:.2f}".format(roc_auc_score(y_test, y_pred_proba_svc)))
# Out:
# AUC Score: 0.85

# %% [markdown]
# Checking the cross validation accuracy of the model -

# %%
from sklearn.model_selection import KFold, cross_val_score
kfold = KFold(n_splits=5)
svc_acc = np.mean(cross_val_score(svc, X, y, cv=kfold, scoring='accuracy')) 
print("Cross Validation Score: {:.2f}".format(svc_acc))
# Out:
# Cross Validation Score: 0.80

# %% [markdown]
# Plotting the ROC Curve -

# %%
fpr_svc, tpr_svc, threshold_svc = roc_curve(y_test, y_pred_proba_svc)
auc_svc = auc(fpr_svc, tpr_svc)

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(8, 5))
plt.plot(fpr_svc, tpr_svc, label="Support Vector Classifier (area = {:.2f})".format(auc_svc))
plt.plot([0, 1], [0, 1], linestyle='--')
plt.legend(loc='lower right', frameon=True)
plt.title("ROC Curve")
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.show()

# %% [markdown]
# # Solution:
# I’ve performed EDA, Data Cleaning & Visualization on the dataset, used Support Vector Classifier for binary
# classification and obtained 80% cross validation accuracy with 0.85 ROC AUC score.

# %% [markdown]
# # THANK YOU
